# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

import plotly.io as pio
pio.renderers.default='browser'

# %%
df1 = pd.read_csv(r"C:\Users\mjouhar\OneDrive - Lowe's Companies Inc\Python 2021- 2022 New\02.Personal projects\Google fit data Analysis\Daily activity metrics.csv", parse_dates=True, index_col='Date')

# %%
df1.head()
# Out:
#             Move Minutes count  Calories (kcal)  Distance (m)  Heart Points  \
# Date
# 2009-01-01                 2.0        45.848943           NaN           4.0
# 2009-01-02                 NaN              NaN           NaN           NaN
# 2009-01-03                 NaN              NaN           NaN           NaN
# 2019-02-27                 NaN       911.644956           NaN           NaN
# 2019-02-28                 NaN      1732.000000           NaN           NaN
#
#             Heart Minutes  Average heart rate (bpm)  Max heart rate (bpm)  \
# Date
# 2009-01-01            2.0                 79.785117                 125.0
# 2009-01-02            NaN                 74.707623                 120.0
# 2009-01-03            NaN                 85.450802                 133.0
# 2019-02-27            NaN                       NaN                   NaN
# 2019-02-28            NaN                       NaN                   NaN
#
#             Min heart rate (bpm)  Low latitude (deg)  Low longitude (deg)  \
# Date
# 2009-01-01                  52.0                 NaN                  NaN
# 2009-01-02                  44.0                 NaN                  NaN
# 2009-01-03                  58.0                 NaN                  NaN
# 2019-02-27                   NaN                 NaN                  NaN
# 2019-02-28                   NaN                 NaN                  NaN
#
#             ...  Stair climbing machine duration (ms)  \
# Date        ...
# 2009-01-01  ...                                   NaN
# 2009-01-02  ...                                   NaN
# 2009-01-03  ...                                   NaN
# 2019-02-27  ...                                   NaN
# 2019-02-28  ...                                   NaN
#
#             Paddle boarding duration (ms)  Strength training duration (ms)  \
# Date
# 2009-01-01                            NaN                              NaN
# 2009-01-02                            NaN                              NaN
# 2009-01-03                            NaN                              NaN
# 2019-02-27                            NaN                              NaN
# 2019-02-28                            NaN                              NaN
#
#             Weight lifting duration (ms)  Other duration (ms)  \
# Date
# 2009-01-01                           NaN                  NaN
# 2009-01-02                           NaN                  NaN
# 2009-01-03                           NaN                  NaN
# 2019-02-27                           NaN                  NaN
# 2019-02-28                           NaN                  NaN
#
#             CrossFit duration (ms)  \
# Date
# 2009-01-01                     NaN
# 2009-01-02                     NaN
# 2009-01-03                     NaN
# 2019-02-27                     NaN
# 2019-02-28                     NaN
#
#             High intensity interval training duration (ms)  \
# Date
# 2009-01-01                                             NaN
# 2009-01-02                                             NaN
# 2009-01-03                                             NaN
# 2019-02-27                                             NaN
# 2019-02-28                                             NaN
#
#             Interval training duration (ms)  Guided breathing duration (ms)  \
# Date
# 2009-01-01                         313780.0                             NaN
# 2009-01-02                              NaN                             NaN
# 2009-01-03                              NaN                             NaN
# 2019-02-27                              NaN                             NaN
# 2019-02-28                              NaN                             NaN
#
#             Paced walking duration (ms)
# Date
# 2009-01-01                          NaN
# 2009-01-02                          NaN
# 2009-01-03                          NaN
# 2019-02-27                          NaN
# 2019-02-28                          NaN
#
# [5 rows x 37 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 457 entries, 2009-01-01 to 2021-11-15
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Move Minutes count                              396 non-null    float64
#  1   Calories (kcal)                                 439 non-null    float64
#  2   Distance (m)                                    405 non-null    float64
#  3   Heart Points                                    251 non-null    float64
#  4   Heart Minutes                                   251 non-null    float64
#  5   Average heart rate (bpm)                        290 non-null    float64
#  6   Max heart rate (bpm)                            290 non-null    float64
#  7   Min heart rate (bpm)                            290 non-null    float64
#  8   Low latitude (deg)                              67 non-null     float64
#  9   Low longitude (deg)                             67 non-null     float64
#  10  High latitude (deg)                             67 non-null     float64
#  11  High longitude (deg)                            67 non-null     float64
#  12  Average speed (m/s)                             405 non-null    float64
#  13  Max speed (m/s)                                 405 non-null    float64
#  14  Min speed (m/s)                                 405 non-null    float64
#  15  Step count                                      410 non-null    float64
#  16  Average weight (kg)                             9 non-null      float64
#  17  Max weight (kg)                                 9 non-null      float64
#  18  Min weight (kg)                                 9 non-null      float64
#  19  Biking duration (ms)                            7 non-null      float64
#  20  Inactive duration (ms)                          38 non-null     float64
#  21  Walking duration (ms)                           332 non-null    float64
#  22  Running duration (ms)                           26 non-null     float64
#  23  Stationary biking duration (ms)                 3 non-null      float64
#  24  Circuit training duration (ms)                  2 non-null      float64
#  25  Cricket duration (ms)                           1 non-null      float64
#  26  Soccer duration (ms)                            4 non-null      float64
#  27  Stair climbing machine duration (ms)            9 non-null      float64
#  28  Paddle boarding duration (ms)                   1 non-null      float64
#  29  Strength training duration (ms)                 15 non-null     float64
#  30  Weight lifting duration (ms)                    8 non-null      float64
#  31  Other duration (ms)                             3 non-null      float64
#  32  CrossFit duration (ms)                          3 non-null      float64
#  33  High intensity interval training duration (ms)  2 non-null      float64
#  34  Interval training duration (ms)                 7 non-null      float64
#  35  Guided breathing duration (ms)                  17 non-null     float64
#  36  Paced walking duration (ms)                     7 non-null      float64
# dtypes: float64(37)
# memory usage: 135.7 KB

# %%
df1.drop(['Average weight (kg)', 'Max weight (kg)', 'Min weight (kg)', 'Average heart rate (bpm)', 'Min heart rate (bpm)', 'Max heart rate (bpm)'], inplace=True, axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 457 entries, 2009-01-01 to 2021-11-15
# Data columns (total 31 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Move Minutes count                              396 non-null    float64
#  1   Calories (kcal)                                 439 non-null    float64
#  2   Distance (m)                                    405 non-null    float64
#  3   Heart Points                                    251 non-null    float64
#  4   Heart Minutes                                   251 non-null    float64
#  5   Low latitude (deg)                              67 non-null     float64
#  6   Low longitude (deg)                             67 non-null     float64
#  7   High latitude (deg)                             67 non-null     float64
#  8   High longitude (deg)                            67 non-null     float64
#  9   Average speed (m/s)                             405 non-null    float64
#  10  Max speed (m/s)                                 405 non-null    float64
#  11  Min speed (m/s)                                 405 non-null    float64
#  12  Step count                                      410 non-null    float64
#  13  Biking duration (ms)                            7 non-null      float64
#  14  Inactive duration (ms)                          38 non-null     float64
#  15  Walking duration (ms)                           332 non-null    float64
#  16  Running duration (ms)                           26 non-null     float64
#  17  Stationary biking duration (ms)                 3 non-null      float64
#  18  Circuit training duration (ms)                  2 non-null      float64
#  19  Cricket duration (ms)                           1 non-null      float64
#  20  Soccer duration (ms)                            4 non-null      float64
#  21  Stair climbing machine duration (ms)            9 non-null      float64
#  22  Paddle boarding duration (ms)                   1 non-null      float64
#  23  Strength training duration (ms)                 15 non-null     float64
#  24  Weight lifting duration (ms)                    8 non-null      float64
#  25  Other duration (ms)                             3 non-null      float64
#  26  CrossFit duration (ms)                          3 non-null      float64
#  27  High intensity interval training duration (ms)  2 non-null      float64
#  28  Interval training duration (ms)                 7 non-null      float64
#  29  Guided breathing duration (ms)                  17 non-null     float64
#  30  Paced walking duration (ms)                     7 non-null      float64
# dtypes: float64(31)
# memory usage: 114.2 KB

# %%
df1["workoutMonth"] = df1.index.month_name()

df1["workoutWeekDay"] = df1.index.day_name()

df1["workoutYear"] = df1.index.year

# %%
df1 = df1[df1["Step count"] > 2000]

# %%
temp1 = df1.workoutMonth.value_counts()
months = ('January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December')
month_value = tuple(temp1[i] for i in months)

fig = px.bar(temp1, 
             x=months, 
             y=month_value, 
             color=month_value, 
             text=month_value,
             color_continuous_scale='Rainbow',
             labels={'color':''}
            )

fig.update_layout(
    title = "Count of Workout in Each Month from 2018 to present",
    xaxis_title='Month',
    yaxis_title='Number of Workouts',
    xaxis_tickangle=-40,
    yaxis={'visible': False, 'showticklabels': False},
    font=dict(size=15)
)

fig.layout.template = 'plotly_dark'

fig.show();

# %%
temp2 = df1.workoutWeekDay.value_counts()
months = ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday')
month_value = tuple(temp2[i] for i in months)

fig = px.bar(temp2, 
             x=months, 
             y=month_value, 
             color=month_value, 
             text=month_value,
             color_continuous_scale='Rainbow',
             labels={'color':''}
            )

fig.update_layout(
    title = "Count of Workout in Each Week Day from 2018 to present",
    xaxis_title='Week Day',
    yaxis_title='Number of Workouts',
    xaxis_tickangle=-40,
    yaxis={'visible': False, 'showticklabels': False},
    font=dict(size=15)
)

fig.layout.template = 'plotly_dark'


fig.show();

# %%
temp3 = df1.workoutYear.value_counts()
fig = go.Figure(data=[go.Pie(labels=temp3.index,
                             values=temp3.values,
                             textinfo='label+percent',
                             pull=[0, 0, 0, 0.2],
                             title="Year's Contribution to Total Workouts"
                             )])

fig.update_traces(hoverinfo='label+value',  textfont_size=15, 
                  marker=dict(line=dict(color='#eff542', width=2)), showlegend=False)

fig.update_layout(font=dict(size=15))

fig.layout.template = 'plotly_dark'

fig.show();

# %%
fig = px.line(df1["Move Minutes count"])

fig.update_layout(
    title = "Move Minutes Line Chart",
    yaxis_title='Move Minutes',
    xaxis_tickangle=-40,
    font=dict(size=15),
    showlegend=False
)

fig.layout.template = 'plotly_dark'


fig.show()

# %%
temp3 = df1.groupby("workoutMonth")['Move Minutes count'].sum()
months = ('January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December')
month_value = tuple(temp3[i] for i in months)

fig = px.bar(temp3, 
             x=months, 
             y=month_value, 
             color=month_value, 
             text=month_value,
             color_continuous_scale='Rainbow',
             labels={'color':''}
            )

fig.update_layout(
    title = "Moving Minutes Per Month",
    xaxis_title='Month',
    yaxis_title='Moving Minutes',
    xaxis_tickangle=-40,
    yaxis={'visible': False, 'showticklabels': False},
    font=dict(size=15)
)

fig.layout.template = 'plotly_dark'


fig.show();

# %%
fig = px.line(df1["Step count"].rolling(window=7).mean())

fig.update_layout(
    title = "Step Count Line Chart",
    yaxis_title='Steps',
    xaxis_tickangle=-40,
    font=dict(size=15),
    showlegend=False
)

fig.layout.template = 'plotly_dark'


fig.show();
